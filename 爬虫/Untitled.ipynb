# %%
import requests
res = requests.get('http://ref.cnki.net/REF/AuthorSearch/Index?authorName=%E6%98%93%E4%B8%B9%E8%BE%89&authorCode=&isJump=true')

# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
res.text
# Out:
# '<!DOCTYPE html>\r\n<html>\r\n<head>\r\n    <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\r\n    <title>作者检索--中国引文数据库版--中国知网</title>\r\n    <link href="/REF/favicon.ico" rel="shortcut icon" type="image/x-icon" />\r\n    <link href="/REF/Content/css/base.css" rel="stylesheet"/>\r\n<link href="/REF/Content/css/CnkiAidInput.css" rel="stylesheet"/>\r\n<link href="/REF/Content/css/refReport.css" rel="stylesheet"/>\r\n\r\n    <script src="/REF/Scripts/jquery-1.8.2.js"></script>\r\n\r\n\r\n    \r\n    \r\n\r\n</head>\r\n<body class="rootw">\r\n    \r\n\r\n\r\n<div class="headerbgN">\r\n    <div class="globalnav01">\r\n        <a href="/REF/">\r\n            <div class="logo02"></div>\r\n        </a>\r\n        <div class="nav02" id="headerTopContainer">\r\n            \t\t欢迎：<a href="/REF/Redirect?type=5" target="_blank">K10093</a>\r\n\t    <span class="line">|</span><a href="/REF/Account/LogOut" class="exit">退出系统</a>\r\n\t    <input type="hidden" id="hidIdentId" val
# ...

# %%
soup = BeautifulSoup(res.text, 'html.parser')
